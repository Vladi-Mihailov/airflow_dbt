# %%
a = 'hello'
b = 'world'
c= 'c'
c= a + ' '+ b

print (c)
# Out:
# hello world

# %%
a = 5
b = 5.5
c= a+b
print (c)
# Out:
# 10.5

# %%
a = 'hello'
b = 2
c= a*b

print (c)
# Out:
# hellohello

# %%
a = int(input("a: "))
b = int(input("b: "))
c = a + b

print (c)
# Out:
# a:  4
# b:  6
# 10

# %%
#Найти количество полных минут в секундах
a = 1470//60
print(a)
# Out:
# 24

# %%
#Найти последнюю цифру числа
a = 1471
a = a % 2
print (a)
# Out:
# 1

# %%
a = 10
b = 5
print(a < b)
# Out:
# False

# %%
a = 10

if a % 2 == 0:
    print('чётное')
else:
    print('нечётное')
# Out:
# чётное

# %%
x =  11

if x < 0: 
    print ('отрицательное')
elif x > 0: 
    print('положительное')
else:
    print ('ноль')
# Out:
# положительное
